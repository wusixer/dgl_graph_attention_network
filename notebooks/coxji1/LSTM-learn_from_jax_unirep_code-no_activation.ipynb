# %%
# %load_ext autoreload
# %autoreload 2

# %%
from functools import partial

import jax.numpy as np
from jax import lax, nn, random, vmap
from jax._src.nn.functions import normalize
from jax.experimental import stax
from jax.nn import sigmoid
from jax.nn.initializers import glorot_normal, normal
from jax.random import normal as norm
from jax import lax

# %%
from patch_gnn.data import load_ghesquire
import pandas as pd
from pyprojroot import here
import pickle as pkl
from patch_gnn.splitting import train_test_split
from jax import random
from patch_gnn.seqops import one_hot
from patch_gnn.unirep import unirep_reps
from patch_gnn.graph import graph_tensors
from patch_gnn.models import MPNN, DeepMPNN
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import explained_variance_score as evs
import matplotlib.pyplot as plt 
from sklearn.metrics import mean_squared_error as mse
import pickle as pkl
from patch_gnn.graph import met_position
import seaborn as sns

# %% [markdown]
# ##### Load dataset, split into train and test, then one hot encode it

# %%
# load graphs
graph_pickle_path = here() / "data/ghesquire_2011/graphs.pkl"
with open(graph_pickle_path, "rb") as f:
    graphs = pkl.load(f)

# load data
data = load_ghesquire()

# filter data based on graphs.keys() and other metrics
filtered = (
   data
   .query("`accession-sequence` in @graphs.keys()")
   .query("ox_fwd_logit < 2.0")
   .join_apply(met_position, "met_position")
)

# split data into train and testing
key = random.PRNGKey(490)
train_df, test_df = train_test_split(key, filtered) # 70% training, 30% testing
print(f"the shape of train_df and test_df are {train_df.shape}, {test_df.shape}")

# pad sequence to 50 length and one hot encode it
padding_length = 50
train_oh = one_hot(train_df, padding_length) 
test_oh = one_hot(test_df,padding_length)
print(f"the shape of train_oh and test_oh are {train_oh.shape}, {test_oh.shape}")
# Out:
# the shape of train_df and test_df are (258, 18), (111, 18)
# the shape of train_oh and test_oh are (258, 1050), (111, 1050)

# %% [markdown]
# ##### reshape data to fit LSTM and get target values

# %%
lstm_train_oh = train_oh.reshape(train_oh.shape[0], padding_length, 21)
lstm_test_oh = test_oh.reshape(test_oh.shape[0], padding_length, 21)
print(lstm_train_oh.shape, lstm_test_oh.shape)
train_target = train_df['ox_fwd_logit'].values
test_target = test_df['ox_fwd_logit'].values
# Out:
# (258, 50, 21) (111, 50, 21)

# %%
batch_size = 1
lstm_train_oh[0:batch_size,:,:].shape, train_target[0:batch_size,].shape
# Out:
# ((1, 50, 21), (1,))

# %% [markdown]
# #### LSTM based on JAX unirep's case study

# %%
def AAEmbedding(embedding_dims: int , E_init=glorot_normal(), **kwargs):
    """
    Initial n-dimensional embedding of each amino-acid, like a dense layer without bias
    """

    def init_fun(rng, input_shape):
        """
        Generates the inital AA embedding matrix.
        `input_shape`:
            one-hot encoded AA sequence -> (n_aa, n_unique_aa)
        `output_dims`:
            embedded sequence -> (n_aa, embedding_dims)
        `emb_matrix`:
            embedding matrix -> (n_unique_aa, embedding_dims)
        """
        emb_matrix = E_init(rng, (input_shape[-1], embedding_dims))
        output_dims = (-1, embedding_dims)#-1 means it can be of any number 
    
        return output_dims, emb_matrix

    def apply_fun(params, inputs, **kwargs):
        """
        Embed a single AA sequence
        """
        emb_matrix = params
        # (n_aa, n_unique_aa) * (n_unique_aa, embedding_dims) => (n_aa, embedding_dims) # noqa: E501
        return np.matmul(inputs, emb_matrix)

    return init_fun, apply_fun

# %%
def LSTM(out_dim, W_init=glorot_normal(), b_init=normal()):
    """
    one directional LSTM, see math here https://d2l.ai/chapter_recurrent-modern/lstm.html
    :params out_dim: number of output neurons associated with an input of a single time point
    
    """
    def init_fun(rng, input_shape):
        """
        initialize LSTM layer for stax
        :param rng: The PRNGKey (from JAX) for random number generation _reproducibility_.
        :params input_shape: (num_time_steps/n_letters, embeddings)
        """
        # initial hidden state and memory state ---- don't set it this way since params are not supposed to be tuple of tuples
        #hidden = b_init(rng, (1, out_dim)) # denote by H in the formula #b_init(rng, (input_shape[0], out_dim)), instead None can be any number
        #memory = b_init(rng, (1, out_dim)) # denote by C in the formula #b_init(rng, (input_shape[0], out_dim))
        # input gate
        k1, k2, k3 = random.split(rng, num=3)
        input_W, input_U, input_b = (
            W_init(k1, (input_shape[-1], out_dim)),
            W_init(k2, (out_dim, out_dim)),
            b_init(k3, (out_dim,)),
        )
        # forget gate
        k1, k2, k3 = random.split(rng, num=3)
        forget_W, forget_U, forget_b = (
            W_init(k1, (input_shape[-1], out_dim)),
            W_init(k2, (out_dim, out_dim)),
            b_init(k3, (out_dim,)),
        )
        # output gate
        k1, k2, k3 = random.split(rng, num=3)
        output_W, output_U, output_b = (
            W_init(k1, (input_shape[-1], out_dim)),
            W_init(k2, (out_dim, out_dim)),
            b_init(k3, (out_dim,)),
        )
        # current memory 
        k1, k2, k3 = random.split(rng, num=3)
        candidate_m_W, candidate_m_U, candidate_m_b = (
            W_init(k1, (input_shape[-1], out_dim)),
            W_init(k2, (out_dim, out_dim)),
            b_init(k3, (out_dim,)),
        )
        
        
        output_shape = (1,out_dim) #(out_dim, )#,input_shape[0] or 1? I think it should be 1 since each sample is input into the algorithm each time. input_shape[0] should be dim of the previous layer
        return (output_shape, (input_W, input_U, input_b, forget_W, forget_U, forget_b, output_W, output_U, output_b, candidate_m_W, candidate_m_U, candidate_m_b))# this tuple is (output_shape, params)
        #return (output_shape,
        #       ((hidden, memory),
        #       (input_W, input_U, input_b),
        #       (forget_W, forget_U, forget_b),
        #       (output_W, output_U, output_b),
        #       (candidate_m_W, candidate_m_U, candidate_m_b)),) # this tuple is (output_shape, params)
    
    def apply_fun(params, inputs, **kwargs):
        """ Loop over the time steps of the input sequence """
        #h_0, m_0 = params[0] # initial hidden and memory, not do it this way since params contain values one is going to optimize
        h_0 = np.zeros((1, out_dim))
        m_0 = np.zeros((1, out_dim))
        #print(f"inputs shape {inputs.shape}")  # input should be (num_timestep, embedding), num_timestep=50

        def apply_fun_scan(params, carry, inputs):
            """ 
            Perform single step update of the network
            carry: a tuple with (hidden, memory)
            :param input: of shape 
            """
            (hidden, memory) = carry  # carry has to be a tuple, b/c this function will be used by lax.scan and it has to be 2 inputs not 3
            input_W, input_U, input_b, forget_W, forget_U, forget_b, output_W, output_U, output_b, candidate_m_W, candidate_m_U, candidate_m_b = params
#             (i,j), (input_W, input_U, input_b), (forget_W, forget_U, forget_b), (
#                 output_W, output_U, output_b),(
#                 candidate_m_W, candidate_m_U, candidate_m_b) = params
            #print(f"input_W shape: {input_W.shape}, input_U shape: {input_U.shape}, input_b shape: {input_b.shape}" )
            # shape annotation: (1,embedding)*(embedding, outdim) +(1, outdim)*(outdim, outdim) => (1, outdim)
            input_gate = sigmoid(np.dot(inputs, input_W) +
                                  np.dot(hidden, input_U) + input_b)
            # shape annotation: (1,embedding)*(embedding, outdim) +(1, outdim)*(outdim, outdim)=> (1, outdim)
            forget_gate = sigmoid(np.dot(inputs, forget_W) +
                                 np.dot(hidden, forget_U) + forget_b)
            # shape annotation: (1,embedding)*(embedding, outdim) +(1, outdim)*(outdim, outdim)=> (1, outdim)
            output_gate = sigmoid(np.dot(inputs, output_W) +
                                 np.dot(hidden, output_U) + output_b)
            # shape annotation: (1,embedding)*(embedding, outdim) +(1, outdim)*(outdim, outdim)=> (1, outdim)
            candidate_memory = np.tanh(np.dot(inputs, candidate_m_W) +
                                 np.dot(hidden, candidate_m_U) + candidate_m_b)
            # shape annotation: (1,outdim)@(1,outdim) + 1,outdim)@(1,outdim)=> (1, outdim)
            #print(f"forget_gate shape: {forget_gate.shape}, memory shape: {memory.shape}, input_gate shape:{input_gate.shape}, cadidate_memory shape: {candidate_memory.shape}")
            current_memory = np.multiply(forget_gate, memory) + np.multiply(input_gate, candidate_memory)
            # shape annotation: (1,outdim)@(1, outdim)=> (1, outdim)
            current_hidden = np.multiply(output_gate, np.tanh(current_memory))
            #print(f"current_memory shape: {current_memory.shape}, hidden shape: {hidden.shape}")
            hidden = current_hidden
            memory = current_memory

            return (hidden, memory), hidden  # it has to be in this format because lax.scan output requires it to be of the shape of the function output

        f = partial(apply_fun_scan, params) # this is a function
        (h_final, m_final), output = lax.scan(f, init=(h_0, m_0), xs=inputs)
        
        #print(f"h_final shape is {h_final.shape}, m_final shape is {m_final.shape}, output shape is {output.shape}")
        return (h_final, m_final), output #h_final shape is (1, outdim), m_final shape is (1, outdim), output shape is (n_timestep, 1, outdim)

    return init_fun, apply_fun

# %%
# need to make another layer between lstm to dense to get rid of the tuple returned by lstm
def LSTMHiddenStates(**kwargs):
    """
    Returns the full hidden states (last element) of the mLSTM layer.
    """

    def init_fun(rng, input_shape):
        output_shape = (input_shape[1],) # input_shape is the output shape of the LSTM, which is specified in the init_func
        return output_shape, ()

    def apply_fun(params, inputs, **kwargs):
        return inputs[0][0] # this is h_final, look at the actual output by lstm (h_final, m_final), output

    return init_fun, apply_fun

# %% [markdown]
# #### next step we want to generate some inputs for LSTM layer for testing

# %%
from jax import value_and_grad, jit,grad
from jax.experimental import stax
from patch_gnn.training import mseloss
from jax.experimental.optimizers import adam
from tqdm.auto import tqdm

# Initialize the network and perform a forward pass
vanilla_lstm_init_fun, vanilla_lstm_apply_fun = stax.serial(
    AAEmbedding(17), 
    #stax.Sigmoid, 
    LSTM(32),
    LSTMHiddenStates(),
    #stax.Relu, don't use relu given the output are mostly negatives
    stax.Dense(1))#Dense(lstm_train_oh.shape[0])

#vanilla_lstm_init_fun, vanilla_lstm_apply_fun = LSTM(32)
_, params = vanilla_lstm_init_fun(key, (lstm_train_oh.shape[0], padding_length, 21)) # params here include params of all layers


def mse_loss(params,predict, inputs, targets):
#    """ Calculate the Mean Squared Error Prediction Loss. """
    preds = predict(params, inputs)
#    preds = vmap(partial(predict, params))(inputs)
    return np.mean((preds - targets)**2)
# the following update function is the same as step function in patch_gnn.training
def fit(
    lstm_train_oh ,
    train_target ,
    num_epochs: int,
    params, #default for params is the pre-trained weights
    #batch_size: int = 25,
    #holdout_seqs: Optional[Iterable[str]] = None,
    #proj_name: str = "temp",
    #epochs_per_print: int = 1,
    step_size: float = 0.0001,
    model_func = vanilla_lstm_apply_fun,
    backend: str = "cpu",
    
):
    """referencing unirep https://github.com/ElArkk/jax-unirep/blob/12209f58165daac30fe0d8e8ccece9d9cdec02e7/jax_unirep/evotuning.py fit function"""
    @jit
    def step(i, x, y, state):
        """ Perform one timestep forward pass of all layers, calculate the MSE & perform a SGD step. """
        params = get_params(state)
        g = grad(partial(mse_loss, predict = model_func))(params, inputs= x, targets = y)
        state = update(i, g, state) # update the state based on gradient using adam
        return state  # states have params in a form adam can use
 
    ########### tell adam about the parameters to optimize, this initlize params for step function
    init, update, get_params = adam(step_size=step_size)
    get_params = jit(get_params)
    state = init(params)
    
    for epoch in tqdm(range(num_epochs)):
        loss_within_epoch = []
        for batch_idx in tqdm(range(lstm_train_oh.shape[0])):
            x_in = lstm_train_oh[batch_idx, :, :]
            y = train_target[batch_idx:batch_idx+1, ]
            for timestep in range(padding_length):
            #print(f"x_in shape is {x_in.shape},y shape is {y.shape}")
                state = step(timestep, x_in, y, state)
                loss = mse_loss(get_params(state),model_func, x_in, y)
                
                # get the loss of last time point
                if timestep == (padding_length-1):
                    # calculate within epoch loss avg
                    loss_within_epoch.append(loss)
                    
                    print(f"loss for time step {timestep} is {loss}")
        avg_loss_in_epoch = np.mean(np.array(loss_within_epoch))
        print(f"average loss for this epoch is {avg_loss_in_epoch}")
    return get_params(state)  # in the end, get the params from the final state

# %%
def predict(tuned_params, test_set_x, test_target, model_apply_fun ):
    """
    predict the output for test set and calculate the loss, returns pred_test: a list, and mse_loss: a float, and explained_var_score: int
    :param tuned_params: the tuned params from training by calling the `fit` function
    :param test_set_x: same shape as train set of shape (n_samples, padding_length, n_unique_letters)
    :param test_target: same shape as train_target, of shape (n_samples, )
    :param model_apply_fun: the apply_fun of the jax.serial model, e.g vanilla_lstm_apply_fun
    """
    pred_test = []
    for batch_idx in tqdm(range(test_set_x.shape[0])):
        pred_test_idx = model_apply_fun(tuned_params, test_set_x[batch_idx,:,: ]) 
        pred_test.append(pred_test_idx)
    # reshape pred_test to ndarray
    pred_test = np.array(pred_test).reshape(len(pred_test),)
    mse_loss = np.mean((pred_test - test_target)**2)
    # explained_var_score from https://scikit-learn.org/stable/modules/model_evaluation.html#explained-variance-score
    explained_var_score = 1- (np.var(test_target - pred_test)/(np.var(test_target)))
    return pred_test, mse_loss, explained_var_score

# %% [markdown]
# ##### If the inputs in LSTM `apply_fun` is reshaped, the dimension problem will be solved but there will be another error
# ###### input: (50,21) --> AAembedding --> (50, 17) --> (1,17) x 50 time steps --> LSTM --> (1,32) after 50 timesteps
# ### The model takes a lot of time to train, each epoch takes 31 min on avg

# %%
tuned_params = fit(lstm_train_oh, train_target, num_epochs=5,  params=params, model_func=vanilla_lstm_apply_fun)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss for time step 49 is 18.59742546081543
# loss for time step 49 is 0.9962432980537415
# loss for time step 49 is 11.814244270324707
# loss for time step 49 is 2.6120314598083496
# loss for time step 49 is 0.46879762411117554
# loss for time step 49 is 1.5499600172042847
# loss for time step 49 is 1.430564284324646
# loss for time step 49 is 3.8444910049438477
# loss for time step 49 is 0.40860000252723694
# loss for time step 49 is 0.1300528198480606
# loss for time step 49 is 0.14892858266830444
# loss for time step 49 is 7.927452564239502
# loss for time step 49 is 0.007338959723711014
# loss for time step 49 is 4.135105609893799
# loss for time step 49 is 0.038845937699079514
# loss for time step 49 is 6.152039051055908
# loss for time step 49 is 0.03727176412940025
# loss for time step 49 is 0.0016681320266798139
# loss for time step 49 is 1.058613657951355
# loss for time step 49 is 0.05477607250213623
# loss for time step 49 is 2.3827483654022217
# loss for time step 49 is 6.097663879394531
# loss for time step 49 is 1.755030632019043
# loss for time step 49 is 0.4116109609603882
# loss for time step 49 is 1.47942054271698
# loss for time step 49 is 0.019695943221449852
# loss for time step 49 is 0.401215136051178
# loss for time step 49 is 2.2130186557769775
# loss for time step 49 is 0.7635046243667603
# loss for time step 49 is 0.8242806196212769
# loss for time step 49 is 1.6886829137802124
# loss for time step 49 is 0.001951001351699233
# loss for time step 49 is 0.8872308731079102
# loss for time step 49 is 1.3299195766448975
# loss for time step 49 is 0.31352558732032776
# loss for time step 49 is 4.854618072509766
# loss for time step 49 is 0.24127037823200226
# loss for time step 49 is 0.8931760787963867
# loss for time step 49 is 1.5887309312820435
# loss for time step 49 is 0.669666588306427
# loss for time step 49 is 4.531083583831787
# loss for time step 49 is 2.9466028213500977
# loss for time step 49 is 1.8744252920150757
# loss for time step 49 is 0.1908310055732727
# loss for time step 49 is 2.0716676712036133
# loss for time step 49 is 2.705864906311035
# loss for time step 49 is 0.2268921285867691
# loss for time step 49 is 4.997748374938965
# loss for time step 49 is 0.17090147733688354
# loss for time step 49 is 0.4244901239871979
# loss for time step 49 is 0.078647181391716
# loss for time step 49 is 3.1961941719055176
# loss for time step 49 is 0.9221444129943848
# loss for time step 49 is 0.03727498650550842
# loss for time step 49 is 4.296632766723633
# loss for time step 49 is 2.347890615463257
# loss for time step 49 is 0.004867034964263439
# loss for time step 49 is 0.6175151467323303
# loss for time step 49 is 0.09293605387210846
# loss for time step 49 is 0.9353564977645874
# loss for time step 49 is 0.20536202192306519
# loss for time step 49 is 4.869418144226074
# loss for time step 49 is 1.2542544603347778
# loss for time step 49 is 0.006673190277069807
# loss for time step 49 is 0.24335803091526031
# loss for time step 49 is 0.6109693646430969
# loss for time step 49 is 1.402368187904358
# loss for time step 49 is 2.9965076446533203
# loss for time step 49 is 0.10727771371603012
# loss for time step 49 is 0.0072458949871361256
# loss for time step 49 is 0.22722432017326355
# loss for time step 49 is 3.4719812870025635
# loss for time step 49 is 0.15723106265068054
# loss for time step 49 is 0.22233645617961884
# loss for time step 49 is 2.0943973064422607
# loss for time step 49 is 1.1725372076034546
# loss for time step 49 is 1.4455080032348633
# loss for time step 49 is 1.4748865365982056
# loss for time step 49 is 0.7478645443916321
# loss for time step 49 is 5.4453253746032715
# loss for time step 49 is 1.7318634986877441
# loss for time step 49 is 1.8323711156845093
# loss for time step 49 is 1.672426700592041
# loss for time step 49 is 1.6228437423706055
# loss for time step 49 is 0.5913211107254028
# loss for time step 49 is 2.6356852054595947
# loss for time step 49 is 2.6848392486572266
# loss for time step 49 is 0.8509906530380249
# loss for time step 49 is 2.811878204345703
# loss for time step 49 is 0.5930876135826111
# loss for time step 49 is 0.27975767850875854
# loss for time step 49 is 0.015237793326377869
# loss for time step 49 is 3.8465757369995117
# loss for time step 49 is 0.04707172513008118
# loss for time step 49 is 1.5956156253814697
# loss for time step 49 is 0.5447702407836914
# loss for time step 49 is 1.0534560680389404
# loss for time step 49 is 2.508683204650879
# loss for time step 49 is 0.7030900716781616
# loss for time step 49 is 0.603355884552002
# loss for time step 49 is 3.5284342765808105
# loss for time step 49 is 0.0765439048409462
# loss for time step 49 is 0.4071177840232849
# loss for time step 49 is 1.0248405933380127
# loss for time step 49 is 1.1897701025009155
# loss for time step 49 is 0.03082198277115822
# loss for time step 49 is 0.00597139447927475
# loss for time step 49 is 0.9747161865234375
# loss for time step 49 is 1.0795249938964844
# loss for time step 49 is 1.1058597564697266
# loss for time step 49 is 2.7799692153930664
# loss for time step 49 is 0.22335119545459747
# loss for time step 49 is 0.0016352941747754812
# loss for time step 49 is 0.6922510266304016
# loss for time step 49 is 1.1600033044815063
# loss for time step 49 is 6.120303153991699
# loss for time step 49 is 0.904513418674469
# loss for time step 49 is 1.4301750659942627
# loss for time step 49 is 0.11016204208135605
# loss for time step 49 is 3.101576805114746
# loss for time step 49 is 0.08340268582105637
# loss for time step 49 is 0.8431521058082581
# loss for time step 49 is 1.3926258087158203
# loss for time step 49 is 0.4853438436985016
# loss for time step 49 is 5.14291524887085
# loss for time step 49 is 0.004529429133981466
# loss for time step 49 is 2.961148977279663
# loss for time step 49 is 0.7358139157295227
# loss for time step 49 is 2.59885835647583
# loss for time step 49 is 3.001666307449341
# loss for time step 49 is 0.33383870124816895
# loss for time step 49 is 0.5085732936859131
# loss for time step 49 is 0.01482117548584938
# loss for time step 49 is 0.00033701586653478444
# loss for time step 49 is 1.146389126777649
# loss for time step 49 is 0.8522130846977234
# loss for time step 49 is 0.37801066040992737
# loss for time step 49 is 3.402799606323242
# loss for time step 49 is 0.5134146809577942
# loss for time step 49 is 0.6205549836158752
# loss for time step 49 is 0.34082502126693726
# loss for time step 49 is 0.26830732822418213
# loss for time step 49 is 1.9476330280303955
# loss for time step 49 is 6.97812032699585
# loss for time step 49 is 0.05800710245966911
# loss for time step 49 is 0.7832129597663879
# loss for time step 49 is 1.4591057300567627
# loss for time step 49 is 0.9326835870742798
# loss for time step 49 is 0.0924932211637497
# loss for time step 49 is 1.0192962884902954
# loss for time step 49 is 0.05878807231783867
# loss for time step 49 is 1.0722440481185913
# loss for time step 49 is 3.8958537578582764
# loss for time step 49 is 1.525890588760376
# loss for time step 49 is 1.6561945676803589
# loss for time step 49 is 4.32959508895874
# loss for time step 49 is 7.425169467926025
# loss for time step 49 is 0.09641508013010025
# loss for time step 49 is 0.0011713742278516293
# loss for time step 49 is 0.008446002379059792
# loss for time step 49 is 4.336252212524414
# loss for time step 49 is 0.3602375388145447
# loss for time step 49 is 0.0699516236782074
# loss for time step 49 is 6.129304885864258
# loss for time step 49 is 3.6747639179229736
# loss for time step 49 is 0.31667158007621765
# loss for time step 49 is 2.7482750415802
# loss for time step 49 is 1.8029565811157227
# loss for time step 49 is 2.619616985321045
# loss for time step 49 is 4.946035861968994
# loss for time step 49 is 0.11717479676008224
# loss for time step 49 is 1.3246855735778809
# loss for time step 49 is 0.051658157259225845
# loss for time step 49 is 0.599289059638977
# loss for time step 49 is 2.846095323562622
# loss for time step 49 is 0.6245954036712646
# loss for time step 49 is 0.19126108288764954
# loss for time step 49 is 0.48807352781295776
# loss for time step 49 is 0.014004274271428585
# loss for time step 49 is 2.475703239440918
# loss for time step 49 is 0.000978828757070005
# loss for time step 49 is 0.01265441533178091
# loss for time step 49 is 1.7530893087387085
# loss for time step 49 is 0.07062074542045593
# loss for time step 49 is 0.1526269167661667
# loss for time step 49 is 4.639904022216797
# loss for time step 49 is 0.44077828526496887
# loss for time step 49 is 2.4570813179016113
# loss for time step 49 is 0.009442958049476147
# loss for time step 49 is 0.6700342297554016
# loss for time step 49 is 2.020305871963501
# loss for time step 49 is 0.15853725373744965
# loss for time step 49 is 4.350555419921875
# loss for time step 49 is 3.6579253673553467
# loss for time step 49 is 1.2892892360687256
# loss for time step 49 is 0.878519594669342
# loss for time step 49 is 0.08957047015428543
# loss for time step 49 is 2.293026924133301
# loss for time step 49 is 0.21026359498500824
# loss for time step 49 is 0.03987889736890793
# loss for time step 49 is 0.8539168238639832
# loss for time step 49 is 0.22391538321971893
# loss for time step 49 is 1.267688512802124
# loss for time step 49 is 0.20742693543434143
# loss for time step 49 is 0.10330143570899963
# loss for time step 49 is 1.005468726158142
# loss for time step 49 is 0.8818457126617432
# loss for time step 49 is 0.9963271021842957
# loss for time step 49 is 0.08204999566078186
# loss for time step 49 is 0.5505096912384033
# loss for time step 49 is 0.27124902606010437
# loss for time step 49 is 0.035670824348926544
# loss for time step 49 is 4.453875541687012
# loss for time step 49 is 1.4797534942626953
# loss for time step 49 is 0.12966971099376678
# loss for time step 49 is 0.45793354511260986
# loss for time step 49 is 4.696113586425781
# loss for time step 49 is 0.21567271649837494
# loss for time step 49 is 0.6291155815124512
# loss for time step 49 is 0.7363072633743286
# loss for time step 49 is 5.578947067260742
# loss for time step 49 is 0.09174375981092453
# loss for time step 49 is 1.0176289081573486
# loss for time step 49 is 0.3046940565109253
# loss for time step 49 is 3.2973899841308594
# loss for time step 49 is 5.419614315032959
# loss for time step 49 is 0.6803135275840759
# loss for time step 49 is 0.15349149703979492
# loss for time step 49 is 0.8808953166007996
# loss for time step 49 is 1.8888511657714844
# loss for time step 49 is 1.43752121925354
# loss for time step 49 is 0.1955149620771408
# loss for time step 49 is 4.021150588989258
# loss for time step 49 is 0.4970591962337494
# loss for time step 49 is 0.38032087683677673
# loss for time step 49 is 0.04838564246892929
# loss for time step 49 is 2.4668896198272705
# loss for time step 49 is 5.26514196395874
# loss for time step 49 is 2.102834701538086
# loss for time step 49 is 5.941307544708252
# loss for time step 49 is 0.14149609208106995
# loss for time step 49 is 4.770031929016113
# loss for time step 49 is 0.005748306401073933
# loss for time step 49 is 0.9991175532341003
# loss for time step 49 is 0.2780250608921051
# loss for time step 49 is 1.861077070236206
# loss for time step 49 is 1.6663557291030884
# loss for time step 49 is 0.38832348585128784
# loss for time step 49 is 0.1918467879295349
# loss for time step 49 is 0.061010755598545074
# loss for time step 49 is 3.8403029441833496
# loss for time step 49 is 0.2902791202068329
# loss for time step 49 is 0.214791938662529
# loss for time step 49 is 0.0013472057180479169
# loss for time step 49 is 0.1272631734609604
# loss for time step 49 is 0.5357896089553833
# loss for time step 49 is 0.2067747414112091
# loss for time step 49 is 0.34606799483299255
# average loss for this epoch is 1.558183193206787
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss for time step 49 is 4.799442291259766
# loss for time step 49 is 1.0219566822052002
# loss for time step 49 is 2.36041522026062
# loss for time step 49 is 0.0082846162840724
# loss for time step 49 is 0.6143854260444641
# loss for time step 49 is 0.0025656037032604218
# loss for time step 49 is 0.03263183683156967
# loss for time step 49 is 1.1729989051818848
# loss for time step 49 is 2.1290953159332275
# loss for time step 49 is 1.2857941389083862
# loss for time step 49 is 0.10649356991052628
# loss for time step 49 is 4.746175765991211
# loss for time step 49 is 0.25444257259368896
# loss for time step 49 is 2.2264463901519775
# loss for time step 49 is 0.4915129542350769
# loss for time step 49 is 4.0633745193481445
# loss for time step 49 is 0.05689254403114319
# loss for time step 49 is 0.12966790795326233
# loss for time step 49 is 1.9818601608276367
# loss for time step 49 is 0.014261547476053238
# loss for time step 49 is 3.5194509029388428
# loss for time step 49 is 4.642489910125732
# loss for time step 49 is 1.0638763904571533
# loss for time step 49 is 0.8433653712272644
# loss for time step 49 is 0.9195024371147156
# loss for time step 49 is 0.14447021484375
# loss for time step 49 is 0.7405195236206055
# loss for time step 49 is 1.633362889289856
# loss for time step 49 is 1.1462132930755615
# loss for time step 49 is 1.1968990564346313
# loss for time step 49 is 1.2657215595245361
# loss for time step 49 is 0.04289047420024872
# loss for time step 49 is 1.1970500946044922
# loss for time step 49 is 1.0207781791687012
# loss for time step 49 is 0.47965267300605774
# loss for time step 49 is 4.323686599731445
# loss for time step 49 is 0.36921799182891846
# loss for time step 49 is 1.1139179468154907
# loss for time step 49 is 1.3406591415405273
# loss for time step 49 is 0.8373302817344666
# loss for time step 49 is 4.160086154937744
# loss for time step 49 is 3.246116876602173
# loss for time step 49 is 2.0929486751556396
# loss for time step 49 is 0.2567419111728668
# loss for time step 49 is 2.227149486541748
# loss for time step 49 is 2.5044147968292236
# loss for time step 49 is 0.2845779359340668
# loss for time step 49 is 4.720080852508545
# loss for time step 49 is 0.1245303526520729
# loss for time step 49 is 0.35445186495780945
# loss for time step 49 is 0.11145305633544922
# loss for time step 49 is 3.0255966186523438
# loss for time step 49 is 0.8428154587745667
# loss for time step 49 is 0.0542093887925148
# loss for time step 49 is 4.4705376625061035
# loss for time step 49 is 2.4655728340148926
# loss for time step 49 is 0.0012139659374952316
# loss for time step 49 is 0.6677914261817932
# loss for time step 49 is 0.10917864739894867
# loss for time step 49 is 0.9676812291145325
# loss for time step 49 is 0.18886731564998627
# loss for time step 49 is 4.740581035614014
# loss for time step 49 is 1.1892669200897217
# loss for time step 49 is 0.0028944513760507107
# loss for time step 49 is 0.2699134647846222
# loss for time step 49 is 0.573641836643219
# loss for time step 49 is 1.4572018384933472
# loss for time step 49 is 2.9210896492004395
# loss for time step 49 is 0.09470520913600922
# loss for time step 49 is 0.004433602560311556
# loss for time step 49 is 0.2436046153306961
# loss for time step 49 is 3.4190328121185303
# loss for time step 49 is 0.14868669211864471
# loss for time step 49 is 0.21448364853858948
# loss for time step 49 is 2.128824234008789
# loss for time step 49 is 1.1517367362976074
# loss for time step 49 is 1.4716702699661255
# loss for time step 49 is 1.5029326677322388
# loss for time step 49 is 0.7298232316970825
# loss for time step 49 is 5.481687068939209
# loss for time step 49 is 1.737916111946106
# loss for time step 49 is 1.755419135093689
# loss for time step 49 is 1.678348183631897
# loss for time step 49 is 1.596511721611023
# loss for time step 49 is 0.5977424383163452
# loss for time step 49 is 2.5709474086761475
# loss for time step 49 is 2.398482322692871
# loss for time step 49 is 0.17915193736553192
# loss for time step 49 is 3.022458076477051
# loss for time step 49 is 0.6438746452331543
# loss for time step 49 is 0.24021859467029572
# loss for time step 49 is 0.026367567479610443
# loss for time step 49 is 3.8866868019104004
# loss for time step 49 is 0.04426218569278717
# loss for time step 49 is 1.5527130365371704
# loss for time step 49 is 0.5583192706108093
# loss for time step 49 is 1.061082124710083
# loss for time step 49 is 2.4777684211730957
# loss for time step 49 is 0.670628011226654
# loss for time step 49 is 0.5440542697906494
# loss for time step 49 is 3.599464178085327
# loss for time step 49 is 0.07229588180780411
# loss for time step 49 is 0.4117787778377533
# loss for time step 49 is 1.0093597173690796
# loss for time step 49 is 1.1458375453948975
# loss for time step 49 is 0.03062281385064125
# loss for time step 49 is 0.005606818478554487
# loss for time step 49 is 0.9612472057342529
# loss for time step 49 is 1.0318350791931152
# loss for time step 49 is 0.9728245735168457
# loss for time step 49 is 1.520627737045288
# loss for time step 49 is 0.00013589675654657185
# loss for time step 49 is 0.02742195874452591
# loss for time step 49 is 0.680633544921875
# loss for time step 49 is 0.9693471789360046
# loss for time step 49 is 5.796463966369629
# loss for time step 49 is 0.9958998560905457
# loss for time step 49 is 1.2920677661895752
# loss for time step 49 is 0.07709117978811264
# loss for time step 49 is 2.8555972576141357
# loss for time step 49 is 0.04831130430102348
# loss for time step 49 is 0.9510916471481323
# loss for time step 49 is 1.2552270889282227
# loss for time step 49 is 0.4089713990688324
# loss for time step 49 is 4.855652809143066
# loss for time step 49 is 0.01680649444460869
# loss for time step 49 is 2.7747883796691895
# loss for time step 49 is 0.8348705172538757
# loss for time step 49 is 2.749816417694092
# loss for time step 49 is 2.8346540927886963
# loss for time step 49 is 0.3871564567089081
# loss for time step 49 is 0.571195662021637
# loss for time step 49 is 0.025893373414874077
# loss for time step 49 is 0.0030622310005128384
# loss for time step 49 is 1.0765599012374878
# loss for time step 49 is 0.7936198115348816
# loss for time step 49 is 0.382294237613678
# loss for time step 49 is 3.2968358993530273
# loss for time step 49 is 0.4815066158771515
# loss for time step 49 is 0.5970067977905273
# loss for time step 49 is 0.33366748690605164
# loss for time step 49 is 0.2790203392505646
# loss for time step 49 is 1.9911680221557617
# loss for time step 49 is 7.097067832946777
# loss for time step 49 is 0.04898693785071373
# loss for time step 49 is 0.8187904357910156
# loss for time step 49 is 1.4970966577529907
# loss for time step 49 is 0.9470037817955017
# loss for time step 49 is 0.08655290305614471
# loss for time step 49 is 1.020745873451233
# loss for time step 49 is 0.05684995651245117
# loss for time step 49 is 1.06332266330719
# loss for time step 49 is 3.839041233062744
# loss for time step 49 is 1.3744996786117554
# loss for time step 49 is 1.7008236646652222
# loss for time step 49 is 4.101291656494141
# loss for time step 49 is 4.652316093444824
# loss for time step 49 is 0.6492204070091248
# loss for time step 49 is 0.10327040404081345
# loss for time step 49 is 0.008173277601599693
# loss for time step 49 is 4.1484856605529785
# loss for time step 49 is 0.3013680577278137
# loss for time step 49 is 0.04428897425532341
# loss for time step 49 is 5.769617557525635
# loss for time step 49 is 3.379575729370117
# loss for time step 49 is 0.3914619982242584
# loss for time step 49 is 2.9624903202056885
# loss for time step 49 is 1.904533863067627
# loss for time step 49 is 2.6407551765441895
# loss for time step 49 is 4.766582489013672
# loss for time step 49 is 0.15024739503860474
# loss for time step 49 is 1.3776205778121948
# loss for time step 49 is 0.0424298495054245
# loss for time step 49 is 0.6246864199638367
# loss for time step 49 is 2.7432620525360107
# loss for time step 49 is 0.5599836707115173
# loss for time step 49 is 0.2224416881799698
# loss for time step 49 is 0.5320654511451721
# loss for time step 49 is 0.020439457148313522
# loss for time step 49 is 2.372277021408081
# loss for time step 49 is 0.004902394022792578
# loss for time step 49 is 0.021837783977389336
# loss for time step 49 is 1.6600621938705444
# loss for time step 49 is 0.052907794713974
# loss for time step 49 is 0.17931020259857178
# loss for time step 49 is 4.48007345199585
# loss for time step 49 is 0.39373597502708435
# loss for time step 49 is 2.3600409030914307
# loss for time step 49 is 0.0045942277647554874
# loss for time step 49 is 0.7189910411834717
# loss for time step 49 is 2.090778112411499
# loss for time step 49 is 0.1381268948316574
# loss for time step 49 is 4.251429080963135
# loss for time step 49 is 3.7448978424072266
# loss for time step 49 is 1.322342872619629
# loss for time step 49 is 0.8421484231948853
# loss for time step 49 is 0.10145427286624908
# loss for time step 49 is 2.3292932510375977
# loss for time step 49 is 0.21523791551589966
# loss for time step 49 is 0.041402172297239304
# loss for time step 49 is 0.8404359221458435
# loss for time step 49 is 0.22433549165725708
# loss for time step 49 is 1.2218661308288574
# loss for time step 49 is 0.2170189917087555
# loss for time step 49 is 0.09106123447418213
# loss for time step 49 is 0.9094196557998657
# loss for time step 49 is 0.6334015727043152
# loss for time step 49 is 0.21519891917705536
# loss for time step 49 is 0.010033220052719116
# loss for time step 49 is 0.5444296002388
# loss for time step 49 is 0.2448764443397522
# loss for time step 49 is 0.016104627400636673
# loss for time step 49 is 4.196002960205078
# loss for time step 49 is 1.5689380168914795
# loss for time step 49 is 0.10654827207326889
# loss for time step 49 is 0.4992440640926361
# loss for time step 49 is 4.455417156219482
# loss for time step 49 is 0.1665751039981842
# loss for time step 49 is 0.529837429523468
# loss for time step 49 is 0.8383710384368896
# loss for time step 49 is 5.288002967834473
# loss for time step 49 is 0.1291172355413437
# loss for time step 49 is 0.907369077205658
# loss for time step 49 is 0.24849428236484528
# loss for time step 49 is 3.116393566131592
# loss for time step 49 is 5.609995365142822
# loss for time step 49 is 0.7358036637306213
# loss for time step 49 is 0.12698239088058472
# loss for time step 49 is 0.8105457425117493
# loss for time step 49 is 1.9693145751953125
# loss for time step 49 is 1.358357310295105
# loss for time step 49 is 0.2217584252357483
# loss for time step 49 is 3.893723726272583
# loss for time step 49 is 0.4575059115886688
# loss for time step 49 is 0.4153059124946594
# loss for time step 49 is 0.03717544302344322
# loss for time step 49 is 2.534440040588379
# loss for time step 49 is 5.304876327514648
# loss for time step 49 is 2.059072971343994
# loss for time step 49 is 5.879354000091553
# loss for time step 49 is 0.1448144167661667
# loss for time step 49 is 4.711203098297119
# loss for time step 49 is 0.009335901588201523
# loss for time step 49 is 1.024074673652649
# loss for time step 49 is 0.2634650766849518
# loss for time step 49 is 1.8036161661148071
# loss for time step 49 is 1.6979753971099854
# loss for time step 49 is 0.36746886372566223
# loss for time step 49 is 0.20285886526107788
# loss for time step 49 is 0.06639993190765381
# loss for time step 49 is 3.7704460620880127
# loss for time step 49 is 0.30883368849754333
# loss for time step 49 is 0.21819467842578888
# loss for time step 49 is 0.0022745782043784857
# loss for time step 49 is 0.13257253170013428
# loss for time step 49 is 0.5410999655723572
# loss for time step 49 is 0.20526188611984253
# loss for time step 49 is 0.34490036964416504
# average loss for this epoch is 1.3838410377502441
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss for time step 49 is 4.730162143707275
# loss for time step 49 is 1.0503517389297485
# loss for time step 49 is 2.3118584156036377
# loss for time step 49 is 0.010603582486510277
# loss for time step 49 is 0.6306643486022949
# loss for time step 49 is 0.001517434255219996
# loss for time step 49 is 0.029330600053071976
# loss for time step 49 is 1.1503232717514038
# loss for time step 49 is 2.15090274810791
# loss for time step 49 is 1.2820056676864624
# loss for time step 49 is 0.10375343263149261
# loss for time step 49 is 4.6988067626953125
# loss for time step 49 is 0.2626168429851532
# loss for time step 49 is 2.1911821365356445
# loss for time step 49 is 0.5059746503829956
# loss for time step 49 is 4.019948959350586
# loss for time step 49 is 0.06162901222705841
# loss for time step 49 is 0.13569650053977966
# loss for time step 49 is 2.003816604614258
# loss for time step 49 is 0.015571044757962227
# loss for time step 49 is 3.4899425506591797
# loss for time step 49 is 4.612440586090088
# loss for time step 49 is 1.0477513074874878
# loss for time step 49 is 0.8609808683395386
# loss for time step 49 is 0.9013589024543762
# loss for time step 49 is 0.14813248813152313
# loss for time step 49 is 0.7509654760360718
# loss for time step 49 is 1.613303303718567
# loss for time step 49 is 1.1503351926803589
# loss for time step 49 is 1.1959513425827026
# loss for time step 49 is 1.2547318935394287
# loss for time step 49 is 0.04497550055384636
# loss for time step 49 is 1.1901594400405884
# loss for time step 49 is 1.0151569843292236
# loss for time step 49 is 0.4744552671909332
# loss for time step 49 is 4.291750431060791
# loss for time step 49 is 0.37795907258987427
# loss for time step 49 is 1.1203019618988037
# loss for time step 49 is 1.3281978368759155
# loss for time step 49 is 0.8432661890983582
# loss for time step 49 is 4.125376224517822
# loss for time step 49 is 3.2620222568511963
# loss for time step 49 is 2.073176622390747
# loss for time step 49 is 0.24221979081630707
# loss for time step 49 is 2.0980594158172607
# loss for time step 49 is 2.531841993331909
# loss for time step 49 is 0.2687135338783264
# loss for time step 49 is 4.694636821746826
# loss for time step 49 is 0.11871643364429474
# loss for time step 49 is 0.34728702902793884
# loss for time step 49 is 0.11639327555894852
# loss for time step 49 is 2.993051767349243
# loss for time step 49 is 0.824693500995636
# loss for time step 49 is 0.05916065350174904
# loss for time step 49 is 4.505268096923828
# loss for time step 49 is 2.4659981727600098
# loss for time step 49 is 0.0013948754640296102
# loss for time step 49 is 0.663942813873291
# loss for time step 49 is 0.09991205483675003
# loss for time step 49 is 0.9145936369895935
# loss for time step 49 is 0.2027331441640854
# loss for time step 49 is 4.711999893188477
# loss for time step 49 is 1.1669338941574097
# loss for time step 49 is 0.0017907212022691965
# loss for time step 49 is 0.27982062101364136
# loss for time step 49 is 0.5601778030395508
# loss for time step 49 is 1.4737149477005005
# loss for time step 49 is 2.886972427368164
# loss for time step 49 is 0.08903397619724274
# loss for time step 49 is 0.0032026530243456364
# loss for time step 49 is 0.2476079761981964
# loss for time step 49 is 3.3829548358917236
# loss for time step 49 is 0.14351719617843628
# loss for time step 49 is 0.20921331644058228
# loss for time step 49 is 2.1523964405059814
# loss for time step 49 is 1.1347010135650635
# loss for time step 49 is 1.4886027574539185
# loss for time step 49 is 1.5147061347961426
# loss for time step 49 is 0.7214820384979248
# loss for time step 49 is 5.447653293609619
# loss for time step 49 is 1.686625599861145
# loss for time step 49 is 1.0407623052597046
# loss for time step 49 is 1.746778964996338
# loss for time step 49 is 1.4952812194824219
# loss for time step 49 is 0.63145512342453
# loss for time step 49 is 2.4021687507629395
# loss for time step 49 is 0.69393390417099
# loss for time step 49 is 0.0015662639634683728
# loss for time step 49 is 2.873321294784546
# loss for time step 49 is 0.5585662126541138
# loss for time step 49 is 0.2776700258255005
# loss for time step 49 is 0.01871914602816105
# loss for time step 49 is 3.6991562843322754
# loss for time step 49 is 0.06703929603099823
# loss for time step 49 is 1.6428172588348389
# loss for time step 49 is 0.4969126284122467
# loss for time step 49 is 0.9868238568305969
# loss for time step 49 is 2.583277702331543
# loss for time step 49 is 0.7121419906616211
# loss for time step 49 is 0.53146892786026
# loss for time step 49 is 3.5759596824645996
# loss for time step 49 is 0.049544807523489
# loss for time step 49 is 0.4656923711299896
# loss for time step 49 is 0.9325836896896362
# loss for time step 49 is 1.1228046417236328
# loss for time step 49 is 0.021299824118614197
# loss for time step 49 is 0.009062507189810276
# loss for time step 49 is 1.0105440616607666
# loss for time step 49 is 1.0647505521774292
# loss for time step 49 is 0.9111049771308899
# loss for time step 49 is 1.1314915418624878
# loss for time step 49 is 0.005637799389660358
# loss for time step 49 is 0.06454426050186157
# loss for time step 49 is 0.691625714302063
# loss for time step 49 is 0.8174492716789246
# loss for time step 49 is 5.500552654266357
# loss for time step 49 is 1.0663152933120728
# loss for time step 49 is 1.1889950037002563
# loss for time step 49 is 0.058957163244485855
# loss for time step 49 is 2.680133104324341
# loss for time step 49 is 0.029222657904028893
# loss for time step 49 is 1.0265332460403442
# loss for time step 49 is 1.1670745611190796
# loss for time step 49 is 0.3663184642791748
# loss for time step 49 is 4.675778865814209
# loss for time step 49 is 0.029335662722587585
# loss for time step 49 is 2.6732585430145264
# loss for time step 49 is 0.9032223224639893
# loss for time step 49 is 2.838787794113159
# loss for time step 49 is 2.7306456565856934
# loss for time step 49 is 0.42132145166397095
# loss for time step 49 is 0.6153624653816223
# loss for time step 49 is 0.03504814952611923
# loss for time step 49 is 0.00651224609464407
# loss for time step 49 is 1.03888738155365
# loss for time step 49 is 0.7607112526893616
# loss for time step 49 is 0.41431915760040283
# loss for time step 49 is 3.22430157661438
# loss for time step 49 is 0.4605313837528229
# loss for time step 49 is 0.5826482772827148
# loss for time step 49 is 0.33207541704177856
# loss for time step 49 is 0.2851737439632416
# loss for time step 49 is 2.0158910751342773
# loss for time step 49 is 7.188233852386475
# loss for time step 49 is 0.043084148317575455
# loss for time step 49 is 0.8487551212310791
# loss for time step 49 is 1.5340476036071777
# loss for time step 49 is 0.9654272794723511
# loss for time step 49 is 0.07889288663864136
# loss for time step 49 is 1.0361621379852295
# loss for time step 49 is 0.05978738144040108
# loss for time step 49 is 1.0527470111846924
# loss for time step 49 is 3.83209228515625
# loss for time step 49 is 1.3039268255233765
# loss for time step 49 is 1.7151973247528076
# loss for time step 49 is 4.0583271980285645
# loss for time step 49 is 4.537235736846924
# loss for time step 49 is 0.6558826565742493
# loss for time step 49 is 0.09967999905347824
# loss for time step 49 is 0.009771324694156647
# loss for time step 49 is 4.013912677764893
# loss for time step 49 is 0.27334076166152954
# loss for time step 49 is 0.03313230350613594
# loss for time step 49 is 5.594629287719727
# loss for time step 49 is 3.2539374828338623
# loss for time step 49 is 0.4193371832370758
# loss for time step 49 is 3.070070266723633
# loss for time step 49 is 1.9403318166732788
# loss for time step 49 is 2.617957353591919
# loss for time step 49 is 4.686595916748047
# loss for time step 49 is 0.16999295353889465
# loss for time step 49 is 1.3978972434997559
# loss for time step 49 is 0.038933105766773224
# loss for time step 49 is 0.6433076858520508
# loss for time step 49 is 2.69891357421875
# loss for time step 49 is 0.529936671257019
# loss for time step 49 is 0.23629502952098846
# loss for time step 49 is 0.5586066246032715
# loss for time step 49 is 0.024732526391744614
# loss for time step 49 is 2.330862522125244
# loss for time step 49 is 0.008095093071460724
# loss for time step 49 is 0.02760767564177513
# loss for time step 49 is 1.6238808631896973
# loss for time step 49 is 0.0466497503221035
# loss for time step 49 is 0.1911696493625641
# loss for time step 49 is 4.41774845123291
# loss for time step 49 is 0.376285582780838
# loss for time step 49 is 2.3290610313415527
# loss for time step 49 is 0.003317679977044463
# loss for time step 49 is 0.7377414703369141
# loss for time step 49 is 2.1119868755340576
# loss for time step 49 is 0.13036856055259705
# loss for time step 49 is 4.216625213623047
# loss for time step 49 is 3.7747013568878174
# loss for time step 49 is 1.3248449563980103
# loss for time step 49 is 0.829973578453064
# loss for time step 49 is 0.1061905026435852
# loss for time step 49 is 2.3404314517974854
# loss for time step 49 is 0.21508507430553436
# loss for time step 49 is 0.04148244857788086
# loss for time step 49 is 0.8296223878860474
# loss for time step 49 is 0.2243359386920929
# loss for time step 49 is 1.1887173652648926
# loss for time step 49 is 0.22228384017944336
# loss for time step 49 is 0.08160383254289627
# loss for time step 49 is 0.844017744064331
# loss for time step 49 is 0.43559160828590393
# loss for time step 49 is 0.10556858777999878
# loss for time step 49 is 0.033079467713832855
# loss for time step 49 is 0.5086156129837036
# loss for time step 49 is 0.24778762459754944
# loss for time step 49 is 0.011580140329897404
# loss for time step 49 is 4.064436912536621
# loss for time step 49 is 1.6025810241699219
# loss for time step 49 is 0.09888233989477158
# loss for time step 49 is 0.5269992351531982
# loss for time step 49 is 4.352113246917725
# loss for time step 49 is 0.14979766309261322
# loss for time step 49 is 0.4883585572242737
# loss for time step 49 is 0.8894587159156799
# loss for time step 49 is 5.171010494232178
# loss for time step 49 is 0.1447548121213913
# loss for time step 49 is 0.8673346638679504
# loss for time step 49 is 0.22924013435840607
# loss for time step 49 is 3.0545318126678467
# loss for time step 49 is 5.656047344207764
# loss for time step 49 is 0.7453417778015137
# loss for time step 49 is 0.12005475908517838
# loss for time step 49 is 0.7872920036315918
# loss for time step 49 is 1.9884337186813354
# loss for time step 49 is 1.3320071697235107
# loss for time step 49 is 0.22912268340587616
# loss for time step 49 is 3.8523733615875244
# loss for time step 49 is 0.44608575105667114
# loss for time step 49 is 0.4265872836112976
# loss for time step 49 is 0.033514343202114105
# loss for time step 49 is 2.5488572120666504
# loss for time step 49 is 5.299929618835449
# loss for time step 49 is 2.051758050918579
# loss for time step 49 is 5.777765274047852
# loss for time step 49 is 0.15072481334209442
# loss for time step 49 is 4.709325790405273
# loss for time step 49 is 0.011066850274801254
# loss for time step 49 is 1.031132459640503
# loss for time step 49 is 0.25894102454185486
# loss for time step 49 is 1.7798088788986206
# loss for time step 49 is 1.7017322778701782
# loss for time step 49 is 0.3592063784599304
# loss for time step 49 is 0.20556141436100006
# loss for time step 49 is 0.06809980422258377
# loss for time step 49 is 3.7448678016662598
# loss for time step 49 is 0.31586748361587524
# loss for time step 49 is 0.21099475026130676
# loss for time step 49 is 0.0024634136352688074
# loss for time step 49 is 0.13209845125675201
# loss for time step 49 is 0.5401533246040344
# loss for time step 49 is 0.20305907726287842
# loss for time step 49 is 0.3483143150806427
# average loss for this epoch is 1.3576709032058716
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss for time step 49 is 4.69990348815918
# loss for time step 49 is 1.0622738599777222
# loss for time step 49 is 2.2896416187286377
# loss for time step 49 is 0.01124989241361618
# loss for time step 49 is 0.633837878704071
# loss for time step 49 is 0.0011862313840538263
# loss for time step 49 is 0.028625717386603355
# loss for time step 49 is 1.1413861513137817
# loss for time step 49 is 2.1530845165252686
# loss for time step 49 is 1.2650389671325684
# loss for time step 49 is 0.0989275574684143
# loss for time step 49 is 4.678248882293701
# loss for time step 49 is 0.2636517286300659
# loss for time step 49 is 2.1730899810791016
# loss for time step 49 is 0.5120922327041626
# loss for time step 49 is 3.9927258491516113
# loss for time step 49 is 0.06466308981180191
# loss for time step 49 is 0.1386091709136963
# loss for time step 49 is 2.0118062496185303
# loss for time step 49 is 0.015622913837432861
# loss for time step 49 is 3.4323055744171143
# loss for time step 49 is 4.604797840118408
# loss for time step 49 is 1.042310357093811
# loss for time step 49 is 0.8714348077774048
# loss for time step 49 is 0.8904317021369934
# loss for time step 49 is 0.14787712693214417
# loss for time step 49 is 0.7546281218528748
# loss for time step 49 is 1.601943016052246
# loss for time step 49 is 1.142234206199646
# loss for time step 49 is 1.184658169746399
# loss for time step 49 is 1.251849889755249
# loss for time step 49 is 0.04570940136909485
# loss for time step 49 is 1.1720653772354126
# loss for time step 49 is 1.0168603658676147
# loss for time step 49 is 0.46038174629211426
# loss for time step 49 is 4.27150821685791
# loss for time step 49 is 0.38347241282463074
# loss for time step 49 is 1.1198543310165405
# loss for time step 49 is 1.3221629858016968
# loss for time step 49 is 0.8436769843101501
# loss for time step 49 is 4.099097728729248
# loss for time step 49 is 3.2666778564453125
# loss for time step 49 is 2.032722234725952
# loss for time step 49 is 0.21680079400539398
# loss for time step 49 is 1.7997260093688965
# loss for time step 49 is 2.5679876804351807
# loss for time step 49 is 0.2440079301595688
# loss for time step 49 is 4.6791605949401855
# loss for time step 49 is 0.11462326347827911
# loss for time step 49 is 0.3462270498275757
# loss for time step 49 is 0.11911683529615402
# loss for time step 49 is 2.9696404933929443
# loss for time step 49 is 0.8113126158714294
# loss for time step 49 is 0.06351714581251144
# loss for time step 49 is 4.536919593811035
# loss for time step 49 is 2.455373764038086
# loss for time step 49 is 0.0019757640548050404
# loss for time step 49 is 0.6608718633651733
# loss for time step 49 is 0.08564484864473343
# loss for time step 49 is 0.8330633640289307
# loss for time step 49 is 0.21891571581363678
# loss for time step 49 is 4.678769588470459
# loss for time step 49 is 1.1443055868148804
# loss for time step 49 is 0.0008592710946686566
# loss for time step 49 is 0.2909432053565979
# loss for time step 49 is 0.5472867488861084
# loss for time step 49 is 1.4911338090896606
# loss for time step 49 is 2.8505094051361084
# loss for time step 49 is 0.08368205279111862
# loss for time step 49 is 0.002100127749145031
# loss for time step 49 is 0.24782630801200867
# loss for time step 49 is 3.346808433532715
# loss for time step 49 is 0.14004160463809967
# loss for time step 49 is 0.20631563663482666
# loss for time step 49 is 2.176988363265991
# loss for time step 49 is 1.1174832582473755
# loss for time step 49 is 1.5062601566314697
# loss for time step 49 is 1.5272762775421143
# loss for time step 49 is 0.7136129140853882
# loss for time step 49 is 5.362138748168945
# loss for time step 49 is 1.5589275360107422
# loss for time step 49 is 0.11582300812005997
# loss for time step 49 is 1.7104694843292236
# loss for time step 49 is 1.5504052639007568
# loss for time step 49 is 0.6041017174720764
# loss for time step 49 is 2.4922659397125244
# loss for time step 49 is 1.2831356525421143
# loss for time step 49 is 0.008498759008944035
# loss for time step 49 is 2.7425315380096436
# loss for time step 49 is 0.5111154317855835
# loss for time step 49 is 0.2938642203807831
# loss for time step 49 is 0.01756577380001545
# loss for time step 49 is 3.6058883666992188
# loss for time step 49 is 0.08118048310279846
# loss for time step 49 is 1.6869721412658691
# loss for time step 49 is 0.4624597430229187
# loss for time step 49 is 0.9541814923286438
# loss for time step 49 is 2.639207124710083
# loss for time step 49 is 0.7365767359733582
# loss for time step 49 is 0.5087829232215881
# loss for time step 49 is 3.6133415699005127
# loss for time step 49 is 0.037039224058389664
# loss for time step 49 is 0.5021851658821106
# loss for time step 49 is 0.8854118585586548
# loss for time step 49 is 1.072140097618103
# loss for time step 49 is 0.016037166118621826
# loss for time step 49 is 0.011141265742480755
# loss for time step 49 is 1.0520325899124146
# loss for time step 49 is 1.10531747341156
# loss for time step 49 is 0.8979254364967346
# loss for time step 49 is 1.1031696796417236
# loss for time step 49 is 0.005428222008049488
# loss for time step 49 is 0.06176130846142769
# loss for time step 49 is 0.7023633718490601
# loss for time step 49 is 0.7637910842895508
# loss for time step 49 is 5.337111949920654
# loss for time step 49 is 1.0785881280899048
# loss for time step 49 is 1.1444804668426514
# loss for time step 49 is 0.05463944748044014
# loss for time step 49 is 2.5864739418029785
# loss for time step 49 is 0.021042698994278908
# loss for time step 49 is 1.0599645376205444
# loss for time step 49 is 1.1250650882720947
# loss for time step 49 is 0.34902694821357727
# loss for time step 49 is 4.5792083740234375
# loss for time step 49 is 0.03837175294756889
# loss for time step 49 is 2.625614881515503
# loss for time step 49 is 0.9447967410087585
# loss for time step 49 is 2.881760358810425
# loss for time step 49 is 2.673229694366455
# loss for time step 49 is 0.43974223732948303
# loss for time step 49 is 0.6425046324729919
# loss for time step 49 is 0.04125753790140152
# loss for time step 49 is 0.009278765879571438
# loss for time step 49 is 1.0227808952331543
# loss for time step 49 is 0.745121955871582
# loss for time step 49 is 0.45446470379829407
# loss for time step 49 is 3.176957845687866
# loss for time step 49 is 0.4457784593105316
# loss for time step 49 is 0.5698437690734863
# loss for time step 49 is 0.3270869255065918
# loss for time step 49 is 0.29187914729118347
# loss for time step 49 is 2.028961181640625
# loss for time step 49 is 7.245084285736084
# loss for time step 49 is 0.03990461304783821
# loss for time step 49 is 0.869562029838562
# loss for time step 49 is 1.5643551349639893
# loss for time step 49 is 0.9860220551490784
# loss for time step 49 is 0.07143521308898926
# loss for time step 49 is 1.0615105628967285
# loss for time step 49 is 0.06653731316328049
# loss for time step 49 is 1.0415334701538086
# loss for time step 49 is 3.870694398880005
# loss for time step 49 is 1.345033884048462
# loss for time step 49 is 1.7108062505722046
# loss for time step 49 is 4.112483501434326
# loss for time step 49 is 4.468440055847168
# loss for time step 49 is 0.5844245553016663
# loss for time step 49 is 0.05562155693769455
# loss for time step 49 is 0.0050599402748048306
# loss for time step 49 is 3.9450292587280273
# loss for time step 49 is 0.265100359916687
# loss for time step 49 is 0.029584715142846107
# loss for time step 49 is 5.530490875244141
# loss for time step 49 is 3.2176246643066406
# loss for time step 49 is 0.41843080520629883
# loss for time step 49 is 3.110172986984253
# loss for time step 49 is 1.9361906051635742
# loss for time step 49 is 2.573587417602539
# loss for time step 49 is 4.663306713104248
# loss for time step 49 is 0.17960098385810852
# loss for time step 49 is 1.3970651626586914
# loss for time step 49 is 0.03840089961886406
# loss for time step 49 is 0.6567727327346802
# loss for time step 49 is 2.687838077545166
# loss for time step 49 is 0.5177661180496216
# loss for time step 49 is 0.24036270380020142
# loss for time step 49 is 0.5748933553695679
# loss for time step 49 is 0.02750244177877903
# loss for time step 49 is 2.3190207481384277
# loss for time step 49 is 0.009928583167493343
# loss for time step 49 is 0.03088974393904209
# loss for time step 49 is 1.615003228187561
# loss for time step 49 is 0.045112527906894684
# loss for time step 49 is 0.19519925117492676
# loss for time step 49 is 4.4000749588012695
# loss for time step 49 is 0.37134137749671936
# loss for time step 49 is 2.3254470825195312
# loss for time step 49 is 0.0030696503818035126
# loss for time step 49 is 0.7427158355712891
# loss for time step 49 is 2.1110286712646484
# loss for time step 49 is 0.12792855501174927
# loss for time step 49 is 4.209073066711426
# loss for time step 49 is 3.7792904376983643
# loss for time step 49 is 1.314902663230896
# loss for time step 49 is 0.8279061913490295
# loss for time step 49 is 0.10756903141736984
# loss for time step 49 is 2.3420798778533936
# loss for time step 49 is 0.2136632651090622
# loss for time step 49 is 0.04145943745970726
# loss for time step 49 is 0.8233886361122131
# loss for time step 49 is 0.22298964858055115
# loss for time step 49 is 1.1691267490386963
# loss for time step 49 is 0.22374370694160461
# loss for time step 49 is 0.0750618502497673
# loss for time step 49 is 0.8040899634361267
# loss for time step 49 is 0.3260025978088379
# loss for time step 49 is 0.0654761865735054
# loss for time step 49 is 0.055740151554346085
# loss for time step 49 is 0.4658936560153961
# loss for time step 49 is 0.2644296884536743
# loss for time step 49 is 0.011334843002259731
# loss for time step 49 is 3.9985344409942627
# loss for time step 49 is 1.6082488298416138
# loss for time step 49 is 0.0982806384563446
# loss for time step 49 is 0.5463965535163879
# loss for time step 49 is 4.30717658996582
# loss for time step 49 is 0.1444883495569229
# loss for time step 49 is 0.46909067034721375
# loss for time step 49 is 0.9174907207489014
# loss for time step 49 is 5.1195831298828125
# loss for time step 49 is 0.150826558470726
# loss for time step 49 is 0.8520022630691528
# loss for time step 49 is 0.22217167913913727
# loss for time step 49 is 3.0312857627868652
# loss for time step 49 is 5.6479411125183105
# loss for time step 49 is 0.7377781271934509
# loss for time step 49 is 0.11964734643697739
# loss for time step 49 is 0.7796909213066101
# loss for time step 49 is 1.9854621887207031
# loss for time step 49 is 1.3232016563415527
# loss for time step 49 is 0.2294793426990509
# loss for time step 49 is 3.8398666381835938
# loss for time step 49 is 0.443943053483963
# loss for time step 49 is 0.42953890562057495
# loss for time step 49 is 0.03208758309483528
# loss for time step 49 is 2.5441153049468994
# loss for time step 49 is 5.278713703155518
# loss for time step 49 is 2.0565543174743652
# loss for time step 49 is 5.644863605499268
# loss for time step 49 is 0.1578584760427475
# loss for time step 49 is 4.7266411781311035
# loss for time step 49 is 0.012097407132387161
# loss for time step 49 is 1.0330458879470825
# loss for time step 49 is 0.25740858912467957
# loss for time step 49 is 1.7667169570922852
# loss for time step 49 is 1.6970826387405396
# loss for time step 49 is 0.35440561175346375
# loss for time step 49 is 0.20556768774986267
# loss for time step 49 is 0.06876903027296066
# loss for time step 49 is 3.7340269088745117
# loss for time step 49 is 0.31881797313690186
# loss for time step 49 is 0.1990189254283905
# loss for time step 49 is 0.0023520016111433506
# loss for time step 49 is 0.1298132985830307
# loss for time step 49 is 0.5383884906768799
# loss for time step 49 is 0.20164039731025696
# loss for time step 49 is 0.3523717522621155
# average loss for this epoch is 1.3469160795211792
#   0%|          | 0/258 [00:00<?, ?it/s]
# loss for time step 49 is 4.682977676391602
# loss for time step 49 is 1.0688676834106445
# loss for time step 49 is 2.2775049209594727
# loss for time step 49 is 0.011048046872019768
# loss for time step 49 is 0.6321151852607727
# loss for time step 49 is 0.0010482395300641656
# loss for time step 49 is 0.02892126888036728
# loss for time step 49 is 1.1387310028076172
# loss for time step 49 is 2.148747205734253
# loss for time step 49 is 1.2424954175949097
# loss for time step 49 is 0.09355896711349487
# loss for time step 49 is 4.665591239929199
# loss for time step 49 is 0.2616361677646637
# loss for time step 49 is 2.1619999408721924
# loss for time step 49 is 0.5146413445472717
# loss for time step 49 is 3.9749815464019775
# loss for time step 49 is 0.06653491407632828
# loss for time step 49 is 0.1395324319601059
# loss for time step 49 is 2.013913631439209
# loss for time step 49 is 0.015071670524775982
# loss for time step 49 is 3.345553159713745
# loss for time step 49 is 4.604922771453857
# loss for time step 49 is 1.0429233312606812
# loss for time step 49 is 0.8801597356796265
# loss for time step 49 is 0.8822617530822754
# loss for time step 49 is 0.1449209600687027
# loss for time step 49 is 0.7560475468635559
# loss for time step 49 is 1.5942097902297974
# loss for time step 49 is 1.1240369081497192
# loss for time step 49 is 1.165485143661499
# loss for time step 49 is 1.252168893814087
# loss for time step 49 is 0.045953888446092606
# loss for time step 49 is 1.1422135829925537
# loss for time step 49 is 1.0223093032836914
# loss for time step 49 is 0.43677809834480286
# loss for time step 49 is 4.25532865524292
# loss for time step 49 is 0.38775673508644104
# loss for time step 49 is 1.1151342391967773
# loss for time step 49 is 1.3192219734191895
# loss for time step 49 is 0.8411731123924255
# loss for time step 49 is 4.075122356414795
# loss for time step 49 is 3.2611947059631348
# loss for time step 49 is 1.9481641054153442
# loss for time step 49 is 0.15307265520095825
# loss for time step 49 is 0.19287370145320892
# loss for time step 49 is 2.6220781803131104
# loss for time step 49 is 0.1938447654247284
# loss for time step 49 is 4.667136192321777
# loss for time step 49 is 0.11276847869157791
# loss for time step 49 is 0.3728978633880615
# loss for time step 49 is 0.11365732550621033
# loss for time step 49 is 2.991194248199463
# loss for time step 49 is 0.8211499452590942
# loss for time step 49 is 0.0641411766409874
# loss for time step 49 is 4.560412883758545
# loss for time step 49 is 2.4056811332702637
# loss for time step 49 is 0.004440240561962128
# loss for time step 49 is 0.6755823493003845
# loss for time step 49 is 0.05852159112691879
# loss for time step 49 is 0.699790358543396
# loss for time step 49 is 0.22918808460235596
# loss for time step 49 is 4.613134860992432
# loss for time step 49 is 1.1214905977249146
# loss for time step 49 is 9.317296644439921e-05
# loss for time step 49 is 0.30734583735466003
# loss for time step 49 is 0.5396803617477417
# loss for time step 49 is 1.515976071357727
# loss for time step 49 is 2.80540132522583
# loss for time step 49 is 0.08062128722667694
# loss for time step 49 is 0.0010700894054025412
# loss for time step 49 is 0.22432172298431396
# loss for time step 49 is 3.3095407485961914
# loss for time step 49 is 0.14488665759563446
# loss for time step 49 is 0.2127472311258316
# loss for time step 49 is 2.2022173404693604
# loss for time step 49 is 1.097804069519043
# loss for time step 49 is 1.5229792594909668
# loss for time step 49 is 1.5405315160751343
# loss for time step 49 is 0.7124504446983337
# loss for time step 49 is 4.964183330535889
# loss for time step 49 is 0.670755922794342
# loss for time step 49 is 0.042537789791822433
# loss for time step 49 is 1.5868785381317139
# loss for time step 49 is 1.6745338439941406
# loss for time step 49 is 0.5377358198165894
# loss for time step 49 is 2.629157066345215
# loss for time step 49 is 1.1198288202285767
# loss for time step 49 is 0.003945029340684414
# loss for time step 49 is 2.5567986965179443
# loss for time step 49 is 0.4366934895515442
# loss for time step 49 is 0.32472315430641174
# loss for time step 49 is 0.015442668460309505
# loss for time step 49 is 3.439019203186035
# loss for time step 49 is 0.11004677414894104
# loss for time step 49 is 1.768546223640442
# loss for time step 49 is 0.4073775112628937
# loss for time step 49 is 0.8932925462722778
# loss for time step 49 is 2.7334578037261963
# loss for time step 49 is 0.7695530652999878
# loss for time step 49 is 0.45853376388549805
# loss for time step 49 is 3.66363263130188
# loss for time step 49 is 0.022430773824453354
# loss for time step 49 is 0.5549312233924866
# loss for time step 49 is 0.8189153671264648
# loss for time step 49 is 0.9968475103378296
# loss for time step 49 is 0.01008661836385727
# loss for time step 49 is 0.013571616262197495
# loss for time step 49 is 1.1010901927947998
# loss for time step 49 is 1.130609154701233
# loss for time step 49 is 0.8125306963920593
# loss for time step 49 is 0.989203691482544
# loss for time step 49 is 0.009407219476997852
# loss for time step 49 is 0.06720440834760666
# loss for time step 49 is 0.723875105381012
# loss for time step 49 is 0.7044563889503479
# loss for time step 49 is 5.132673263549805
# loss for time step 49 is 1.0701862573623657
# loss for time step 49 is 1.0898492336273193
# loss for time step 49 is 0.049699146300554276
# loss for time step 49 is 2.45371150970459
# loss for time step 49 is 0.011792385019361973
# loss for time step 49 is 1.1038241386413574
# loss for time step 49 is 1.0679895877838135
# loss for time step 49 is 0.3217950165271759
# loss for time step 49 is 4.4237518310546875
# loss for time step 49 is 0.055822476744651794
# loss for time step 49 is 2.538270950317383
# loss for time step 49 is 1.0156384706497192
# loss for time step 49 is 2.9603588581085205
# loss for time step 49 is 2.57934308052063
# loss for time step 49 is 0.4725984036922455
# loss for time step 49 is 0.6864283084869385
# loss for time step 49 is 0.052222225815057755
# loss for time step 49 is 0.01449477020651102
# loss for time step 49 is 0.9956673979759216
# loss for time step 49 is 0.7179492712020874
# loss for time step 49 is 0.4979117810726166
# loss for time step 49 is 3.098236083984375
# loss for time step 49 is 0.42090603709220886
# loss for time step 49 is 0.5466963648796082
# loss for time step 49 is 0.31552255153656006
# loss for time step 49 is 0.30526652932167053
# loss for time step 49 is 2.0557680130004883
# loss for time step 49 is 7.331829071044922
# loss for time step 49 is 0.03546816483139992
# loss for time step 49 is 0.9017629623413086
# loss for time step 49 is 1.6087758541107178
# loss for time step 49 is 1.014222264289856
# loss for time step 49 is 0.061955925077199936
# loss for time step 49 is 1.0929995775222778
# loss for time step 49 is 0.07466216385364532
# loss for time step 49 is 1.027848243713379
# loss for time step 49 is 3.9100472927093506
# loss for time step 49 is 1.359098196029663
# loss for time step 49 is 1.7193351984024048
# loss for time step 49 is 4.0980224609375
# loss for time step 49 is 4.400968074798584
# loss for time step 49 is 0.4720206558704376
# loss for time step 49 is 0.03238045796751976
# loss for time step 49 is 0.004687504377216101
# loss for time step 49 is 3.950965404510498
# loss for time step 49 is 0.2655046284198761
# loss for time step 49 is 0.0281797107309103
# loss for time step 49 is 5.450499534606934
# loss for time step 49 is 3.151937484741211
# loss for time step 49 is 0.42226770520210266
# loss for time step 49 is 3.1590640544891357
# loss for time step 49 is 1.9107866287231445
# loss for time step 49 is 2.466472864151001
# loss for time step 49 is 4.649343013763428
# loss for time step 49 is 0.18782949447631836
# loss for time step 49 is 1.3627434968948364
# loss for time step 49 is 0.041809312999248505
# loss for time step 49 is 0.6538766622543335
# loss for time step 49 is 2.689913272857666
# loss for time step 49 is 0.5012014508247375
# loss for time step 49 is 0.2450612336397171
# loss for time step 49 is 0.5924016237258911
# loss for time step 49 is 0.029712922871112823
# loss for time step 49 is 2.297748565673828
# loss for time step 49 is 0.012843068689107895
# loss for time step 49 is 0.036067865788936615
# loss for time step 49 is 1.5966472625732422
# loss for time step 49 is 0.04137937352061272
# loss for time step 49 is 0.20322757959365845
# loss for time step 49 is 4.351869106292725
# loss for time step 49 is 0.3561265170574188
# loss for time step 49 is 2.297255039215088
# loss for time step 49 is 0.0020153196528553963
# loss for time step 49 is 0.7607983946800232
# loss for time step 49 is 2.1233863830566406
# loss for time step 49 is 0.1211184710264206
# loss for time step 49 is 4.1747636795043945
# loss for time step 49 is 3.8058924674987793
# loss for time step 49 is 1.3078935146331787
# loss for time step 49 is 0.8179274797439575
# loss for time step 49 is 0.1116906926035881
# loss for time step 49 is 2.3457860946655273
# loss for time step 49 is 0.2096492052078247
# loss for time step 49 is 0.04068547487258911
# loss for time step 49 is 0.7990871071815491
# loss for time step 49 is 0.22507192194461823
# loss for time step 49 is 1.1134004592895508
# loss for time step 49 is 0.2326609343290329
# loss for time step 49 is 0.06168714910745621
# loss for time step 49 is 0.7013960480690002
# loss for time step 49 is 0.17453210055828094
# loss for time step 49 is 0.03488940745592117
# loss for time step 49 is 0.0891304686665535
# loss for time step 49 is 0.432228684425354
# loss for time step 49 is 0.2695731818675995
# loss for time step 49 is 0.00957377627491951
# loss for time step 49 is 3.9100139141082764
# loss for time step 49 is 1.6198631525039673
# loss for time step 49 is 0.09918200969696045
# loss for time step 49 is 0.5624039769172668
# loss for time step 49 is 4.236049175262451
# loss for time step 49 is 0.1326735019683838
# loss for time step 49 is 0.4344226121902466
# loss for time step 49 is 0.9640114307403564
# loss for time step 49 is 5.010284900665283
# loss for time step 49 is 0.1663619726896286
# loss for time step 49 is 0.815260648727417
# loss for time step 49 is 0.20456500351428986
# loss for time step 49 is 2.9666311740875244
# loss for time step 49 is 5.66982889175415
# loss for time step 49 is 0.7371741533279419
# loss for time step 49 is 0.11545667052268982
# loss for time step 49 is 0.75742506980896
# loss for time step 49 is 1.99001145362854
# loss for time step 49 is 1.298452377319336
# loss for time step 49 is 0.2337004393339157
# loss for time step 49 is 3.7987167835235596
# loss for time step 49 is 0.4337258040904999
# loss for time step 49 is 0.44147437810897827
# loss for time step 49 is 0.028393598273396492
# loss for time step 49 is 2.5464932918548584
# loss for time step 49 is 5.218252182006836
# loss for time step 49 is 2.0618956089019775
# loss for time step 49 is 5.307067394256592
# loss for time step 49 is 0.1780436933040619
# loss for time step 49 is 4.736629486083984
# loss for time step 49 is 0.014840860851109028
# loss for time step 49 is 1.0415558815002441
# loss for time step 49 is 0.25260815024375916
# loss for time step 49 is 1.7351890802383423
# loss for time step 49 is 1.6965975761413574
# loss for time step 49 is 0.3427228629589081
# loss for time step 49 is 0.2066156268119812
# loss for time step 49 is 0.07038702070713043
# loss for time step 49 is 3.7030303478240967
# loss for time step 49 is 0.3267296552658081
# loss for time step 49 is 0.1789451241493225
# loss for time step 49 is 0.0022520064376294613
# loss for time step 49 is 0.1268494725227356
# loss for time step 49 is 0.5355023741722107
# loss for time step 49 is 0.19737626612186432
# loss for time step 49 is 0.3583301305770874
# average loss for this epoch is 1.3217732906341553

# %% [markdown]
# #### Save tuned params

# %%
import pickle
with open('aa_embed_17_sigmoid_lstm_32_lstm_hiddenstate_dense_no_sigmoid_5_epochs_weights.pkl', 'wb') as f:
    pickle.dump(tuned_params, f)

# %%
#with open('aa_embed_17_sigmoid_lstm_32_lstm_hiddenstate_dense_5_epochs_weights.pkl', 'rb') as f:
#    new_weights = pickle.load(f)

# %% [markdown]
# #### Evaluate on test set

# %%
pred_train, train_mse_loss, train_explained_var_score =  predict(tuned_params=tuned_params, 
                                                    test_set_x=lstm_train_oh, test_target = train_target, model_apply_fun=vanilla_lstm_apply_fun )
# Out:
#   0%|          | 0/258 [00:00<?, ?it/s]

# %%
pred_test, test_mse_loss, test_explained_var_score =  predict(tuned_params=tuned_params, 
                                                    test_set_x=lstm_test_oh, test_target = test_target, model_apply_fun=vanilla_lstm_apply_fun )
# Out:
#   0%|          | 0/111 [00:00<?, ?it/s]

# %%
def plot_y_eq_x(ax):
    xmin, xmax = ax.get_xlim()
    ymin, ymax = ax.get_ylim()

    minval = min(xmin, ymin)
    maxval = max(xmax, ymax)

    ax.plot([minval, maxval], [minval, maxval])


fig, ax = plt.subplots(
        figsize=(10, 5), nrows=1, ncols=2, sharex=True, sharey=True,
    )


ax[0].scatter(train_target, pred_train)
ax[0].set_title(f"Vanilla_LSTM, Train MSE: {train_mse_loss:.2f},evs: {train_explained_var_score:.2f}")
plot_y_eq_x(ax[0])


ax[1].scatter(test_target, pred_test)
ax[1].set_title(f"Vanilla_LSTM, Test MSE: {test_mse_loss:.2f},evs: {test_explained_var_score:.2f}")
plot_y_eq_x(ax[1])

# %% [markdown]
# ### Conclusion
#
# It seems that many people are observing the model predicts the same outputs when using RNN models https://github.com/keras-team/keras/issues/6447, there are several solutions suggested by this github issues and I'm summarizing here:
#
#
#
# - try reducing batch_size -> the batch size in the LSTM is 1, nothing to reduce any further
# - figure out if there are NaN values in the dataset --> I looked and didn't find any
# - Use the right activation function -> in this notebook, I removed the only activation function in the layer, it seemed to perform slightly better
# - Use fewer layers --> currently, it is already the simplest model
# - data augmentation, increase the size of the data -> not applicable
# - scaling inputs --> currently using sigmoid to scale the embedding to (0,1), didn't help
# - reduce the number of neurons per layer -> currently the embedding layer neuron is 17, and LSTM cells are 32. Might not worth shrinking further
#
# #### What I'ved learned
#
# - The profermance is low probably because we have limited training set
# - One need to be careful about what activation function to use for sequence model, it might be a good idea to start with no activation function

# %% [markdown]
# # below code can be useful and was useful at some point

# %%
from jax.experimental.optimizers import adam
# Defining an optimizer in Jax
step_size = 1e-3
opt_init, opt_update, get_params = adam(step_size)
opt_state = opt_init(params)

num_epochs = 10

# %%
# Loop over the training epochs
loss = []
for epoch in range(num_epochs):
    for batch_idx in range(lstm_train_oh.shape[0]):
        x_in = lstm_train_oh[batch_idx, :, :]
        y = train_target[batch_idx:batch_idx+1, ]
        print(type(x_in), type(y))
        loss, grads = value_and_grad(mse_loss)(params, x_in, y)
        print(loss, grads)
        #params, opt_state, loss = update(params, x_in, y, opt_state)
        #train_loss_log.append(loss)

# %% [markdown]
# ##### below part is what we want to do ultimately

# %%
from jax.experimental import stax
from jax.experimental.optimizers import adam
class VanillaLSTM:
    """Vanilla shallow LSTM model in sklearn-compatible format.

    Forward direction LSTM + linear regression on top.
    """

    def __init__(
        self,
        one_hot_encoded_shape,
        #node_feature_shape,
        #num_adjacency,
        num_training_steps: int = 100,
        optimizer_step_size=1e-5,
    ):
        """
        :param one_hot_encoded_shape: (batch_size, timestep, embedding), timestep is the padding_length
        
        """
        model_init_fun, model_apply_fun = stax.serial(
            Dense(64), 
            stax.Sigmoid, 
            LSTM(32), 
            Dense(1)
        )
        self.model_apply_fun = model_apply_fun

        self.optimizer = adam(step_size=optimizer_step_size)

        output_shape, params = model_init_fun(
            PRNGKey(42), input_shape=(*one_hot_encoded_shape)
        )

        self.params = params
        self.num_training_steps = num_training_steps
        self.state_history = []
        self.loss_history = []

    def fit(self, X, y):
        """Fit model.

        :param X: tuple(timestep, embedding)
        :param y: vector(values to predict)
        """
        if len(y.shape) == 1:
            y = np.reshape(y, (-1, 1))
        init, update, get_params = self.optimizer
        training_step = partial(
            step,
            loss_fun=mseloss,
            apply_fun=self.model_apply_fun,
            update_fun=update,
            get_params=get_params,
            inputs=X,
            outputs=y,
        )
        training_step = jit(training_step)

        state = init(self.params)

        for i in tqdm(range(self.num_training_steps)):
            state, loss = training_step(i, state)
            self.state_history.append(state)
            self.loss_history.append(loss)

        self.params = get_params(state)
        return self

    def predict(self, X, checkpoint: int = None):
        """
        predict
        :param X: tuple(adjacency, node_features)
        """
        params = self.params
        if checkpoint:
            _, _, get_params = self.optimizer
            params = get_params(self.state_history[checkpoint])
        return vmap(partial(self.model_apply_fun, params))(X)

# %%
num_training_steps = 50
model_vanilla_lstm = VanillaLSTM(
    one_hot_encoded_shape = (padding_length, 21)
    num_training_steps=num_training_steps
)
model_vanilla_lstm.fit(lstm_train_oh, train_target)

# %% [markdown]
# ## Case study: GRU
# ### Implementation of GRU from https://towardsdatascience.com/getting-started-with-jax-mlps-cnns-rnns-d0bc389bd683
# ##### formula of GRU can be found at https://www.google.com/search?q=GRU+formula&tbm=isch&source=iu&ictx=1&fir=VgQCUBNNXFcaTM%252CXHoefSnHEDF68M%252C_&vet=1&usg=AI4_-kSHwsjZClZeI1h2s23kwDj5ncW6Jg&sa=X&ved=2ahUKEwjcwZaW8vjvAhUHKFkFHc8NC8sQ9QF6BAgNEAE&biw=1680&bih=895#imgrc=VgQCUBNNXFcaTM
# ##### machanism of GRU can be found at https://d2l.ai/chapter_recurrent-modern/gru.html

# %%
from jax.nn import sigmoid
from jax.nn.initializers import glorot_normal, normal

from functools import partial
from jax import lax

def GRU(out_dim, W_init=glorot_normal(), b_init=normal()):
    def init_fun(rng, input_shape):
        """ Initialize the GRU layer for stax """
        # input shape is of (batch_size, num_time_steps, embeddings)
        hidden = b_init(rng, (input_shape[0], out_dim))

        k1, k2, k3 = random.split(rng, num=3)
        update_W, update_U, update_b = (
            W_init(k1, (input_shape[2], out_dim)),
            W_init(k2, (out_dim, out_dim)),
            b_init(k3, (out_dim,)),)

        k1, k2, k3 = random.split(rng, num=3)
        reset_W, reset_U, reset_b = (
            W_init(k1, (input_shape[2], out_dim)),
            W_init(k2, (out_dim, out_dim)),
            b_init(k3, (out_dim,)),)

        k1, k2, k3 = random.split(rng, num=3)
        out_W, out_U, out_b = (
            W_init(k1, (input_shape[2], out_dim)),
            W_init(k2, (out_dim, out_dim)),
            b_init(k3, (out_dim,)),)
        # Input dim 0 represents the batch dimension
        # Input dim 1 represents the time dimension (before scan moveaxis)
        output_shape = (input_shape[0], input_shape[1], out_dim)
        return (output_shape,
            (hidden,
             (update_W, update_U, update_b),
             (reset_W, reset_U, reset_b),
             (out_W, out_U, out_b),),)

    def apply_fun(params, inputs, **kwargs):
        """ Loop over the time steps of the input sequence """
        h = params[0]
        
        def apply_fun_scan(params, hidden, inp):
            """ Perform single step update of the network """
            _, (update_W, update_U, update_b), (reset_W, reset_U, reset_b), (
                out_W, out_U, out_b) = params

            update_gate = sigmoid(np.dot(inp, update_W) +
                                  np.dot(hidden, update_U) + update_b)
            reset_gate = sigmoid(np.dot(inp, reset_W) +
                                 np.dot(hidden, reset_U) + reset_b)
            output_gate = np.tanh(np.dot(inp, out_W) 
                                  + np.dot(np.multiply(reset_gate, hidden), out_U) 
                                  + out_b)
            output = np.multiply(update_gate, hidden) + np.multiply(1-update_gate, output_gate)
            hidden = output
            return hidden, hidden

        # Move the time dimension to position 0
        inputs = np.moveaxis(inputs, 1, 0)
        f = partial(apply_fun_scan, params)
        _, h_new = lax.scan(f, h, inputs)
        return h_new

    return init_fun, apply_fun

# %%
num_dims = 10              # Number of OU timesteps
batch_size = 64            # Batchsize
num_hidden_units = 12      # GRU cells in the RNN layer 

# Initialize the network and perform a forward pass
init_fun, gru_rnn = stax.serial(Dense(num_hidden_units), Relu,
                                GRU(num_hidden_units), Dense(1))
_, params = init_fun(key, (batch_size, num_dims, 1))

def mse_loss(params, inputs, targets):
    """ Calculate the Mean Squared Error Prediction Loss. """
    preds = gru_rnn(params, inputs)
    return np.mean((preds - targets)**2)

@jit
def update(params, x, y, opt_state):
    """ Perform a forward pass, calculate the MSE & perform a SGD step. """
    loss, grads = value_and_grad(mse_loss)(params, x, y)
    opt_state = opt_update(0, grads, opt_state)
    return get_params(opt_state), opt_state, loss
